# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
# import tensorflow as tf
# print(tf.__version__)

# import os
# from google.colab import drive 
# drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# %cd 'gdrive/My Drive'
# os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
# %cd cupoy_cv_part4 # 可以自己改路徑

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = 'training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# Using TensorFlow backend.

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
#model = get_model()
# 配置 loss funtion 和 optimizer
#model.compile(loss='mean_squared_error', optimizer='adam')

# %%
# 印出網路結構
#model.summary()

# %%
#from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
#checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
#hist = History()

# %%
# training the model
#hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
#                       points_train, 
#                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
#                       shuffle=True, epochs=150, verbose=1)
# save the model weights
#model.save_weights('weights.h5')
# save the model
#model.save('model.h5')

# %%
# loss 值的圖
#plt.title('Optimizer : Adam', fontsize=10)
#plt.ylabel('Loss', fontsize=16)
#plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
#plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
#plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
#imgs_test, _ = load_data(dirname = 'test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
#def plot_keypoints(img, points):
#    plt.imshow(img, cmap='gray')
#    for i in range(0,30,2):
#        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
#fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
#points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

#for i in range(16):
#    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
#    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
# 實現圖片以及關機點 label 做左右翻轉的函數
# Your code

def augment_data(img, points):
    rows, cols = img.shape
    new_img = np.copy(img)
    
    # 翻轉圖片
    for i in range(96):
        for j in range(48):
            temp = img[i][j]
            new_img[i][j] = img[i][cols-j-1]
            new_img[i][cols-j-1] = temp
            
    # 翻轉關鍵點 label
    new_points = np.copy(points)
    for i in range(0,30,2):
        new_points[i] = -points[i]
    
    # 調整對稱的 label
    new_points_temp = np.copy(new_points)
    new_points[0:2] = new_points_temp[2:4]
    new_points[2:4] = new_points_temp[0:2]
    new_points[4:6] = new_points_temp[8:10]
    new_points[6:8] = new_points_temp[10:12]
    new_points[8:10] = new_points_temp[4:6]
    new_points[10:12] = new_points_temp[6:8]
    new_points[12:14] = new_points_temp[16:18]
    new_points[14:16] = new_points_temp[18:20]
    new_points[16:18] = new_points_temp[12:14]
    new_points[18:20] = new_points_temp[14:16]
    new_points[22:24] = new_points_temp[24:26]
    new_points[24:26] = new_points_temp[22:24]
        
    return new_img, new_points

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
flip_img, flip_points = augment_data(imgs_train[0], points_train[0])

fig = plt.figure()
ax = fig.add_subplot(1, 2, 1, xticks=[], yticks=[])
plot_keypoints(imgs_train[0], points_train[0]) # 原來的圖片
ax = fig.add_subplot(1, 2, 2, xticks=[], yticks=[])
plot_keypoints(flip_img, flip_points) # 翻轉後的圖片

# %%
# 創建 list
aug_imgs_train = []
aug_points_train = []

# 對所有原始資料做 augmentation
for i in range(imgs_train.shape[0]):
    # 做左右翻轉
    aug_img, aug_point = augment_data(imgs_train[i], points_train[i])
    
    # append 原始資料
    aug_imgs_train.append(imgs_train[i])
    aug_points_train.append(points_train[i]) 
    
    # append 做過 augmentation 後的資料
    aug_imgs_train.append(aug_img)
    aug_points_train.append(aug_point) 

# convert to numpy
aug_imgs_train = np.array(aug_imgs_train)   
aug_points_train = np.copy(aug_points_train)

print(aug_imgs_train.shape)
print(aug_points_train.shape)
# Out:
# (4280, 96, 96)
# (4280, 30)

# %%
from keras.callbacks import ModelCheckpoint, History

# model checkpoint 
checkpoint_aug = ModelCheckpoint('best_weights_augment.h5', verbose=1, save_best_only=True)
hist = History()

# training the model
hist_model_aug = model_with_augment.fit(aug_imgs_train.reshape(aug_imgs_train.shape[0], 96, 96, 1), aug_points_train, 
                           validation_split=0.2, batch_size=64, callbacks=[checkpoint_aug, hist],
                           shuffle=True, epochs=150, verbose=1)
# Out:
# Train on 3424 samples, validate on 856 samples
# Epoch 1/150
# 3424/3424 [==============================] - 3s 888us/step - loss: 0.0045 - val_loss: 0.0021
#
# Epoch 00001: val_loss improved from inf to 0.00207, saving model to best_weights_augment.h5
# Epoch 2/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 0.0013 - val_loss: 0.0019
#
# Epoch 00002: val_loss improved from 0.00207 to 0.00187, saving model to best_weights_augment.h5
# Epoch 3/150
# 3424/3424 [==============================] - 1s 235us/step - loss: 0.0011 - val_loss: 0.0019
#
# Epoch 00003: val_loss improved from 0.00187 to 0.00186, saving model to best_weights_augment.h5
# Epoch 4/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 9.8614e-04 - val_loss: 0.0017
#
# Epoch 00004: val_loss improved from 0.00186 to 0.00171, saving model to best_weights_augment.h5
# Epoch 5/150
# 3424/3424 [==============================] - 1s 235us/step - loss: 7.8944e-04 - val_loss: 0.0016
#
# Epoch 00005: val_loss improved from 0.00171 to 0.00156, saving model to best_weights_augment.h5
# Epoch 6/150
# 3424/3424 [==============================] - 1s 234us/step - loss: 6.1622e-04 - val_loss: 0.0012
#
# Epoch 00006: val_loss improved from 0.00156 to 0.00117, saving model to best_weights_augment.h5
# Epoch 7/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 5.2439e-04 - val_loss: 0.0010
#
# Epoch 00007: val_loss improved from 0.00117 to 0.00103, saving model to best_weights_augment.h5
# Epoch 8/150
# 3424/3424 [==============================] - 1s 235us/step - loss: 4.6910e-04 - val_loss: 9.2240e-04
#
# Epoch 00008: val_loss improved from 0.00103 to 0.00092, saving model to best_weights_augment.h5
# Epoch 9/150
# 3424/3424 [==============================] - 1s 235us/step - loss: 4.2697e-04 - val_loss: 9.0897e-04
#
# Epoch 00009: val_loss improved from 0.00092 to 0.00091, saving model to best_weights_augment.h5
# Epoch 10/150
# 3424/3424 [==============================] - 1s 237us/step - loss: 3.9253e-04 - val_loss: 8.5046e-04
#
# Epoch 00010: val_loss improved from 0.00091 to 0.00085, saving model to best_weights_augment.h5
# Epoch 11/150
# 3424/3424 [==============================] - 1s 237us/step - loss: 3.6257e-04 - val_loss: 8.7774e-04
#
# Epoch 00011: val_loss did not improve from 0.00085
# Epoch 12/150
# 3424/3424 [==============================] - 1s 237us/step - loss: 3.4318e-04 - val_loss: 7.7394e-04
#
# Epoch 00012: val_loss improved from 0.00085 to 0.00077, saving model to best_weights_augment.h5
# Epoch 13/150
# 3424/3424 [==============================] - 1s 235us/step - loss: 3.2269e-04 - val_loss: 7.7986e-04
#
# Epoch 00013: val_loss did not improve from 0.00077
# Epoch 14/150
# 3424/3424 [==============================] - 1s 237us/step - loss: 3.0765e-04 - val_loss: 7.2294e-04
#
# Epoch 00014: val_loss improved from 0.00077 to 0.00072, saving model to best_weights_augment.h5
# Epoch 15/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 2.8929e-04 - val_loss: 7.3708e-04
#
# Epoch 00015: val_loss did not improve from 0.00072
# Epoch 16/150
# 3424/3424 [==============================] - 1s 238us/step - loss: 2.7650e-04 - val_loss: 6.6344e-04
#
# Epoch 00016: val_loss improved from 0.00072 to 0.00066, saving model to best_weights_augment.h5
# Epoch 17/150
# 3424/3424 [==============================] - 1s 237us/step - loss: 2.6844e-04 - val_loss: 6.6609e-04
#
# Epoch 00017: val_loss did not improve from 0.00066
# Epoch 18/150
# 3424/3424 [==============================] - 1s 237us/step - loss: 2.5830e-04 - val_loss: 6.6502e-04
#
# Epoch 00018: val_loss did not improve from 0.00066
# Epoch 19/150
# 3424/3424 [==============================] - 1s 235us/step - loss: 2.5393e-04 - val_loss: 6.7478e-04
#
# Epoch 00019: val_loss did not improve from 0.00066
# Epoch 20/150
# 3424/3424 [==============================] - 1s 235us/step - loss: 2.4345e-04 - val_loss: 6.4142e-04
#
# Epoch 00020: val_loss improved from 0.00066 to 0.00064, saving model to best_weights_augment.h5
# Epoch 21/150
# 3424/3424 [==============================] - 1s 235us/step - loss: 2.3628e-04 - val_loss: 6.5053e-04
#
# Epoch 00021: val_loss did not improve from 0.00064
# Epoch 22/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 2.2952e-04 - val_loss: 6.3852e-04
#
# Epoch 00022: val_loss improved from 0.00064 to 0.00064, saving model to best_weights_augment.h5
# Epoch 23/150
# 3424/3424 [==============================] - 1s 234us/step - loss: 2.2478e-04 - val_loss: 6.4955e-04
#
# Epoch 00023: val_loss did not improve from 0.00064
# Epoch 24/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 2.1748e-04 - val_loss: 6.2721e-04
#
# Epoch 00024: val_loss improved from 0.00064 to 0.00063, saving model to best_weights_augment.h5
# Epoch 25/150
# 3424/3424 [==============================] - 1s 234us/step - loss: 2.0948e-04 - val_loss: 6.1094e-04
#
# Epoch 00025: val_loss improved from 0.00063 to 0.00061, saving model to best_weights_augment.h5
# Epoch 26/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 2.1080e-04 - val_loss: 6.7801e-04
#
# Epoch 00026: val_loss did not improve from 0.00061
# Epoch 27/150
# 3424/3424 [==============================] - 1s 235us/step - loss: 2.0361e-04 - val_loss: 6.1399e-04
#
# Epoch 00027: val_loss did not improve from 0.00061
# Epoch 28/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 1.9936e-04 - val_loss: 6.6247e-04
#
# Epoch 00028: val_loss did not improve from 0.00061
# Epoch 29/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 1.9650e-04 - val_loss: 6.3132e-04
#
# Epoch 00029: val_loss did not improve from 0.00061
# Epoch 30/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 1.8789e-04 - val_loss: 6.0614e-04
#
# Epoch 00030: val_loss improved from 0.00061 to 0.00061, saving model to best_weights_augment.h5
# Epoch 31/150
# 3424/3424 [==============================] - 1s 235us/step - loss: 1.8561e-04 - val_loss: 6.3634e-04
#
# Epoch 00031: val_loss did not improve from 0.00061
# Epoch 32/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 1.8280e-04 - val_loss: 6.4112e-04
#
# Epoch 00032: val_loss did not improve from 0.00061
# Epoch 33/150
# 3424/3424 [==============================] - 1s 237us/step - loss: 1.8639e-04 - val_loss: 6.5235e-04
#
# Epoch 00033: val_loss did not improve from 0.00061
# Epoch 34/150
# 3424/3424 [==============================] - 1s 237us/step - loss: 1.8152e-04 - val_loss: 6.4262e-04
#
# Epoch 00034: val_loss did not improve from 0.00061
# Epoch 35/150
# 3424/3424 [==============================] - 1s 238us/step - loss: 1.7751e-04 - val_loss: 6.5170e-04
#
# Epoch 00035: val_loss did not improve from 0.00061
# Epoch 36/150
# 3424/3424 [==============================] - 1s 237us/step - loss: 1.7391e-04 - val_loss: 5.8791e-04
#
# Epoch 00036: val_loss improved from 0.00061 to 0.00059, saving model to best_weights_augment.h5
# Epoch 37/150
# 3424/3424 [==============================] - 1s 235us/step - loss: 1.6229e-04 - val_loss: 5.8419e-04
#
# Epoch 00037: val_loss improved from 0.00059 to 0.00058, saving model to best_weights_augment.h5
# Epoch 38/150
# 3424/3424 [==============================] - 1s 235us/step - loss: 1.6348e-04 - val_loss: 6.0413e-04
#
# Epoch 00038: val_loss did not improve from 0.00058
# Epoch 39/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 1.6211e-04 - val_loss: 6.2842e-04
#
# Epoch 00039: val_loss did not improve from 0.00058
# Epoch 40/150
# 3424/3424 [==============================] - 1s 235us/step - loss: 1.5756e-04 - val_loss: 6.1200e-04
#
# Epoch 00040: val_loss did not improve from 0.00058
# Epoch 41/150
# 3424/3424 [==============================] - 1s 235us/step - loss: 1.5471e-04 - val_loss: 5.8669e-04
#
# Epoch 00041: val_loss did not improve from 0.00058
# Epoch 42/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 1.5507e-04 - val_loss: 6.2113e-04
#
# Epoch 00042: val_loss did not improve from 0.00058
# Epoch 43/150
# 3424/3424 [==============================] - 1s 234us/step - loss: 1.5199e-04 - val_loss: 6.2733e-04
#
# Epoch 00043: val_loss did not improve from 0.00058
# Epoch 44/150
# 3424/3424 [==============================] - 1s 237us/step - loss: 1.5077e-04 - val_loss: 6.0991e-04
#
# Epoch 00044: val_loss did not improve from 0.00058
# Epoch 45/150
# 3424/3424 [==============================] - 1s 235us/step - loss: 1.4724e-04 - val_loss: 6.0492e-04
#
# Epoch 00045: val_loss did not improve from 0.00058
# Epoch 46/150
# 3424/3424 [==============================] - 1s 234us/step - loss: 1.4771e-04 - val_loss: 6.1062e-04
#
# Epoch 00046: val_loss did not improve from 0.00058
# Epoch 47/150
# 3424/3424 [==============================] - 1s 234us/step - loss: 1.4580e-04 - val_loss: 6.4001e-04
#
# Epoch 00047: val_loss did not improve from 0.00058
# Epoch 48/150
# 3424/3424 [==============================] - 1s 234us/step - loss: 1.4015e-04 - val_loss: 5.9905e-04
#
# Epoch 00048: val_loss did not improve from 0.00058
# Epoch 49/150
# 3424/3424 [==============================] - 1s 233us/step - loss: 1.4078e-04 - val_loss: 6.0158e-04
#
# Epoch 00049: val_loss did not improve from 0.00058
# Epoch 50/150
# 3424/3424 [==============================] - 1s 234us/step - loss: 1.3880e-04 - val_loss: 5.7891e-04
#
# Epoch 00050: val_loss improved from 0.00058 to 0.00058, saving model to best_weights_augment.h5
# Epoch 51/150
# 3424/3424 [==============================] - 1s 234us/step - loss: 1.3818e-04 - val_loss: 6.0488e-04
#
# Epoch 00051: val_loss did not improve from 0.00058
# Epoch 52/150
# 3424/3424 [==============================] - 1s 235us/step - loss: 1.3458e-04 - val_loss: 6.2809e-04
#
# Epoch 00052: val_loss did not improve from 0.00058
# Epoch 53/150
# 3424/3424 [==============================] - 1s 235us/step - loss: 1.3288e-04 - val_loss: 5.9649e-04
#
# Epoch 00053: val_loss did not improve from 0.00058
# Epoch 54/150
# 3424/3424 [==============================] - 1s 235us/step - loss: 1.3085e-04 - val_loss: 5.7672e-04
#
# Epoch 00054: val_loss improved from 0.00058 to 0.00058, saving model to best_weights_augment.h5
# Epoch 55/150
# 3424/3424 [==============================] - 1s 239us/step - loss: 1.2674e-04 - val_loss: 6.2894e-04
#
# Epoch 00055: val_loss did not improve from 0.00058
# Epoch 56/150
# 3424/3424 [==============================] - 1s 240us/step - loss: 1.2622e-04 - val_loss: 5.8947e-04
#
# Epoch 00056: val_loss did not improve from 0.00058
# Epoch 57/150
# 3424/3424 [==============================] - 1s 242us/step - loss: 1.2746e-04 - val_loss: 5.8639e-04
#
# Epoch 00057: val_loss did not improve from 0.00058
# Epoch 58/150
# 3424/3424 [==============================] - 1s 243us/step - loss: 1.2284e-04 - val_loss: 5.9255e-04
#
# Epoch 00058: val_loss did not improve from 0.00058
# Epoch 59/150
# 3424/3424 [==============================] - 1s 239us/step - loss: 1.2363e-04 - val_loss: 6.0315e-04
#
# Epoch 00059: val_loss did not improve from 0.00058
# Epoch 60/150
# 3424/3424 [==============================] - ETA: 0s - loss: 1.2380e-0 - 1s 237us/step - loss: 1.2360e-04 - val_loss: 5.9485e-04
#
# Epoch 00060: val_loss did not improve from 0.00058
# Epoch 61/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 1.1988e-04 - val_loss: 6.1823e-04
#
# Epoch 00061: val_loss did not improve from 0.00058
# Epoch 62/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 1.1834e-04 - val_loss: 6.2754e-04
#
# Epoch 00062: val_loss did not improve from 0.00058
# Epoch 63/150
# 3424/3424 [==============================] - 1s 235us/step - loss: 1.1913e-04 - val_loss: 5.8952e-04
#
# Epoch 00063: val_loss did not improve from 0.00058
# Epoch 64/150
# 3424/3424 [==============================] - 1s 239us/step - loss: 1.1531e-04 - val_loss: 5.9757e-04
#
# Epoch 00064: val_loss did not improve from 0.00058
# Epoch 65/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 1.1893e-04 - val_loss: 6.3538e-04
#
# Epoch 00065: val_loss did not improve from 0.00058
# Epoch 66/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 1.1559e-04 - val_loss: 6.0790e-04
#
# Epoch 00066: val_loss did not improve from 0.00058
# Epoch 67/150
# 3424/3424 [==============================] - 1s 239us/step - loss: 1.1275e-04 - val_loss: 5.9841e-04
#
# Epoch 00067: val_loss did not improve from 0.00058
# Epoch 68/150
# 3424/3424 [==============================] - 1s 238us/step - loss: 1.1090e-04 - val_loss: 5.8483e-04
#
# Epoch 00068: val_loss did not improve from 0.00058
# Epoch 69/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 1.1131e-04 - val_loss: 5.9982e-04
#
# Epoch 00069: val_loss did not improve from 0.00058
# Epoch 70/150
# 3424/3424 [==============================] - 1s 237us/step - loss: 1.0824e-04 - val_loss: 5.9701e-04
#
# Epoch 00070: val_loss did not improve from 0.00058
# Epoch 71/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 1.0880e-04 - val_loss: 6.0510e-04
#
# Epoch 00071: val_loss did not improve from 0.00058
# Epoch 72/150
# 3424/3424 [==============================] - 1s 238us/step - loss: 1.0733e-04 - val_loss: 6.0207e-04
#
# Epoch 00072: val_loss did not improve from 0.00058
# Epoch 73/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 1.0683e-04 - val_loss: 5.8027e-04
#
# Epoch 00073: val_loss did not improve from 0.00058
# Epoch 74/150
# 3424/3424 [==============================] - 1s 237us/step - loss: 1.0682e-04 - val_loss: 6.0277e-04
#
# Epoch 00074: val_loss did not improve from 0.00058
# Epoch 75/150
# 3424/3424 [==============================] - 1s 238us/step - loss: 1.0639e-04 - val_loss: 6.0719e-04
#
# Epoch 00075: val_loss did not improve from 0.00058
# Epoch 76/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 1.0867e-04 - val_loss: 5.9991e-04
#
# Epoch 00076: val_loss did not improve from 0.00058
# Epoch 77/150
# 3424/3424 [==============================] - 1s 237us/step - loss: 1.0425e-04 - val_loss: 5.8574e-04
#
# Epoch 00077: val_loss did not improve from 0.00058
# Epoch 78/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 1.0411e-04 - val_loss: 5.7213e-04
#
# Epoch 00078: val_loss improved from 0.00058 to 0.00057, saving model to best_weights_augment.h5
# Epoch 79/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 1.0044e-04 - val_loss: 6.0066e-04
#
# Epoch 00079: val_loss did not improve from 0.00057
# Epoch 80/150
# 3424/3424 [==============================] - 1s 237us/step - loss: 9.7951e-05 - val_loss: 5.8948e-04
#
# Epoch 00080: val_loss did not improve from 0.00057
# Epoch 81/150
# 3424/3424 [==============================] - 1s 237us/step - loss: 9.9177e-05 - val_loss: 5.9334e-04
#
# Epoch 00081: val_loss did not improve from 0.00057
# Epoch 82/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 9.8664e-05 - val_loss: 5.7971e-04
#
# Epoch 00082: val_loss did not improve from 0.00057
# Epoch 83/150
# 3424/3424 [==============================] - 1s 234us/step - loss: 1.0023e-04 - val_loss: 5.8957e-04
#
# Epoch 00083: val_loss did not improve from 0.00057
# Epoch 84/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 9.5818e-05 - val_loss: 6.3233e-04
#
# Epoch 00084: val_loss did not improve from 0.00057
# Epoch 85/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 9.7225e-05 - val_loss: 5.9382e-04
#
# Epoch 00085: val_loss did not improve from 0.00057
# Epoch 86/150
# 3424/3424 [==============================] - 1s 237us/step - loss: 9.5138e-05 - val_loss: 5.8110e-04
#
# Epoch 00086: val_loss did not improve from 0.00057
# Epoch 87/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 9.4920e-05 - val_loss: 6.0965e-04
#
# Epoch 00087: val_loss did not improve from 0.00057
# Epoch 88/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 9.7421e-05 - val_loss: 5.7122e-04
#
# Epoch 00088: val_loss improved from 0.00057 to 0.00057, saving model to best_weights_augment.h5
# Epoch 89/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 9.3697e-05 - val_loss: 5.8491e-04
#
# Epoch 00089: val_loss did not improve from 0.00057
# Epoch 90/150
# 3424/3424 [==============================] - 1s 235us/step - loss: 9.4486e-05 - val_loss: 5.9275e-04
#
# Epoch 00090: val_loss did not improve from 0.00057
# Epoch 91/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 9.0677e-05 - val_loss: 5.9356e-04
#
# Epoch 00091: val_loss did not improve from 0.00057
# Epoch 92/150
# 3424/3424 [==============================] - 1s 235us/step - loss: 9.1736e-05 - val_loss: 5.9488e-04
#
# Epoch 00092: val_loss did not improve from 0.00057
# Epoch 93/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 9.1358e-05 - val_loss: 5.9805e-04
#
# Epoch 00093: val_loss did not improve from 0.00057
# Epoch 94/150
# 3424/3424 [==============================] - 1s 235us/step - loss: 9.0327e-05 - val_loss: 6.0411e-04
#
# Epoch 00094: val_loss did not improve from 0.00057
# Epoch 95/150
# 3424/3424 [==============================] - 1s 237us/step - loss: 9.3177e-05 - val_loss: 5.9984e-04
#
# Epoch 00095: val_loss did not improve from 0.00057
# Epoch 96/150
# 3424/3424 [==============================] - 1s 237us/step - loss: 8.9036e-05 - val_loss: 5.9389e-04
#
# Epoch 00096: val_loss did not improve from 0.00057
# Epoch 97/150
# 3424/3424 [==============================] - 1s 238us/step - loss: 8.7929e-05 - val_loss: 5.9796e-04
#
# Epoch 00097: val_loss did not improve from 0.00057
# Epoch 98/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 9.0019e-05 - val_loss: 5.8126e-04
#
# Epoch 00098: val_loss did not improve from 0.00057
# Epoch 99/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 8.8621e-05 - val_loss: 5.9738e-04
#
# Epoch 00099: val_loss did not improve from 0.00057
# Epoch 100/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 8.8184e-05 - val_loss: 6.0070e-04
#
# Epoch 00100: val_loss did not improve from 0.00057
# Epoch 101/150
# 3424/3424 [==============================] - 1s 235us/step - loss: 8.8401e-05 - val_loss: 5.6485e-04
#
# Epoch 00101: val_loss improved from 0.00057 to 0.00056, saving model to best_weights_augment.h5
# Epoch 102/150
# 3424/3424 [==============================] - 1s 237us/step - loss: 8.8311e-05 - val_loss: 5.9571e-04
#
# Epoch 00102: val_loss did not improve from 0.00056
# Epoch 103/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 8.5891e-05 - val_loss: 5.9863e-04
#
# Epoch 00103: val_loss did not improve from 0.00056
# Epoch 104/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 8.6076e-05 - val_loss: 5.9967e-04
#
# Epoch 00104: val_loss did not improve from 0.00056
# Epoch 105/150
# 3424/3424 [==============================] - 1s 237us/step - loss: 8.5507e-05 - val_loss: 5.9015e-04
#
# Epoch 00105: val_loss did not improve from 0.00056
# Epoch 106/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 8.4602e-05 - val_loss: 5.9399e-04
#
# Epoch 00106: val_loss did not improve from 0.00056
# Epoch 107/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 9.0947e-05 - val_loss: 5.9966e-04
#
# Epoch 00107: val_loss did not improve from 0.00056
# Epoch 108/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 8.7062e-05 - val_loss: 5.7949e-04
#
# Epoch 00108: val_loss did not improve from 0.00056
# Epoch 109/150
# 3424/3424 [==============================] - 1s 238us/step - loss: 8.7151e-05 - val_loss: 5.9133e-04
#
# Epoch 00109: val_loss did not improve from 0.00056
# Epoch 110/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 8.7004e-05 - val_loss: 6.2324e-04
#
# Epoch 00110: val_loss did not improve from 0.00056
# Epoch 111/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 8.4273e-05 - val_loss: 5.9997e-04
#
# Epoch 00111: val_loss did not improve from 0.00056
# Epoch 112/150
# 3424/3424 [==============================] - 1s 235us/step - loss: 8.6080e-05 - val_loss: 5.8889e-04
#
# Epoch 00112: val_loss did not improve from 0.00056
# Epoch 113/150
# 3424/3424 [==============================] - 1s 235us/step - loss: 8.3698e-05 - val_loss: 6.0541e-04
#
# Epoch 00113: val_loss did not improve from 0.00056
# Epoch 114/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 8.2080e-05 - val_loss: 5.8448e-04
#
# Epoch 00114: val_loss did not improve from 0.00056
# Epoch 115/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 8.3875e-05 - val_loss: 5.8819e-04
#
# Epoch 00115: val_loss did not improve from 0.00056
# Epoch 116/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 8.3938e-05 - val_loss: 6.0137e-04
#
# Epoch 00116: val_loss did not improve from 0.00056
# Epoch 117/150
# 3424/3424 [==============================] - 1s 244us/step - loss: 8.4032e-05 - val_loss: 6.1362e-04
#
# Epoch 00117: val_loss did not improve from 0.00056
# Epoch 118/150
# 3424/3424 [==============================] - 1s 241us/step - loss: 8.0662e-05 - val_loss: 5.8184e-04
#
# Epoch 00118: val_loss did not improve from 0.00056
# Epoch 119/150
# 3424/3424 [==============================] - 1s 244us/step - loss: 8.3225e-05 - val_loss: 5.7773e-04
#
# Epoch 00119: val_loss did not improve from 0.00056
# Epoch 120/150
# 3424/3424 [==============================] - 1s 243us/step - loss: 8.4412e-05 - val_loss: 6.1145e-04
#
# Epoch 00120: val_loss did not improve from 0.00056
# Epoch 121/150
# 3424/3424 [==============================] - 1s 239us/step - loss: 8.2047e-05 - val_loss: 5.9809e-04
#
# Epoch 00121: val_loss did not improve from 0.00056
# Epoch 122/150
# 3424/3424 [==============================] - 1s 240us/step - loss: 7.9540e-05 - val_loss: 5.8938e-04
#
# Epoch 00122: val_loss did not improve from 0.00056
# Epoch 123/150
# 3424/3424 [==============================] - 1s 238us/step - loss: 7.7988e-05 - val_loss: 5.9586e-04
#
# Epoch 00123: val_loss did not improve from 0.00056
# Epoch 124/150
# 3424/3424 [==============================] - 1s 235us/step - loss: 8.0750e-05 - val_loss: 5.9705e-04
#
# Epoch 00124: val_loss did not improve from 0.00056
# Epoch 125/150
# 3424/3424 [==============================] - 1s 239us/step - loss: 7.9933e-05 - val_loss: 5.8411e-04
#
# Epoch 00125: val_loss did not improve from 0.00056
# Epoch 126/150
# 3424/3424 [==============================] - 1s 238us/step - loss: 7.9589e-05 - val_loss: 5.9212e-04
#
# Epoch 00126: val_loss did not improve from 0.00056
# Epoch 127/150
# 3424/3424 [==============================] - 1s 239us/step - loss: 7.8136e-05 - val_loss: 5.8567e-04
#
# Epoch 00127: val_loss did not improve from 0.00056
# Epoch 128/150
# 3424/3424 [==============================] - 1s 238us/step - loss: 7.6561e-05 - val_loss: 6.1053e-04
#
# Epoch 00128: val_loss did not improve from 0.00056
# Epoch 129/150
# 3424/3424 [==============================] - 1s 238us/step - loss: 7.9670e-05 - val_loss: 6.1416e-04
#
# Epoch 00129: val_loss did not improve from 0.00056
# Epoch 130/150
# 3424/3424 [==============================] - 1s 238us/step - loss: 7.8592e-05 - val_loss: 5.9571e-04
#
# Epoch 00130: val_loss did not improve from 0.00056
# Epoch 131/150
# 3424/3424 [==============================] - 1s 238us/step - loss: 7.7769e-05 - val_loss: 5.7454e-04
#
# Epoch 00131: val_loss did not improve from 0.00056
# Epoch 132/150
# 3424/3424 [==============================] - 1s 238us/step - loss: 8.2278e-05 - val_loss: 6.1012e-04
#
# Epoch 00132: val_loss did not improve from 0.00056
# Epoch 133/150
# 3424/3424 [==============================] - 1s 238us/step - loss: 7.8101e-05 - val_loss: 5.9630e-04
#
# Epoch 00133: val_loss did not improve from 0.00056
# Epoch 134/150
# 3424/3424 [==============================] - 1s 239us/step - loss: 7.5650e-05 - val_loss: 6.0519e-04
#
# Epoch 00134: val_loss did not improve from 0.00056
# Epoch 135/150
# 3424/3424 [==============================] - ETA: 0s - loss: 7.7418e-0 - 1s 239us/step - loss: 7.7444e-05 - val_loss: 5.9902e-04
#
# Epoch 00135: val_loss did not improve from 0.00056
# Epoch 136/150
# 3424/3424 [==============================] - 1s 237us/step - loss: 7.7126e-05 - val_loss: 6.0746e-04
#
# Epoch 00136: val_loss did not improve from 0.00056
# Epoch 137/150
# 3424/3424 [==============================] - 1s 239us/step - loss: 7.7387e-05 - val_loss: 5.8644e-04
#
# Epoch 00137: val_loss did not improve from 0.00056
# Epoch 138/150
# 3424/3424 [==============================] - 1s 238us/step - loss: 7.8035e-05 - val_loss: 5.8122e-04
#
# Epoch 00138: val_loss did not improve from 0.00056
# Epoch 139/150
# 3424/3424 [==============================] - 1s 238us/step - loss: 7.6416e-05 - val_loss: 5.9502e-04
#
# Epoch 00139: val_loss did not improve from 0.00056
# Epoch 140/150
# 3424/3424 [==============================] - 1s 241us/step - loss: 7.6760e-05 - val_loss: 5.8081e-04
#
# Epoch 00140: val_loss did not improve from 0.00056
# Epoch 141/150
# 3424/3424 [==============================] - 1s 243us/step - loss: 7.6501e-05 - val_loss: 6.0040e-04
#
# Epoch 00141: val_loss did not improve from 0.00056
# Epoch 142/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 7.5889e-05 - val_loss: 5.9429e-04
#
# Epoch 00142: val_loss did not improve from 0.00056
# Epoch 143/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 7.4619e-05 - val_loss: 6.1717e-04
#
# Epoch 00143: val_loss did not improve from 0.00056
# Epoch 144/150
# 3424/3424 [==============================] - 1s 235us/step - loss: 7.7764e-05 - val_loss: 6.0948e-04
#
# Epoch 00144: val_loss did not improve from 0.00056
# Epoch 145/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 7.6501e-05 - val_loss: 6.0604e-04
#
# Epoch 00145: val_loss did not improve from 0.00056
# Epoch 146/150
# 3424/3424 [==============================] - 1s 235us/step - loss: 7.6374e-05 - val_loss: 6.1070e-04
#
# Epoch 00146: val_loss did not improve from 0.00056
# Epoch 147/150
# 3424/3424 [==============================] - 1s 239us/step - loss: 7.4379e-05 - val_loss: 6.4644e-04
#
# Epoch 00147: val_loss did not improve from 0.00056
# Epoch 148/150
# 3424/3424 [==============================] - 1s 238us/step - loss: 7.7211e-05 - val_loss: 6.2228e-04
#
# Epoch 00148: val_loss did not improve from 0.00056
# Epoch 149/150
# 3424/3424 [==============================] - 1s 238us/step - loss: 7.4868e-05 - val_loss: 6.1433e-04
#
# Epoch 00149: val_loss did not improve from 0.00056
# Epoch 150/150
# 3424/3424 [==============================] - 1s 237us/step - loss: 7.3955e-05 - val_loss: 5.9566e-04
#
# Epoch 00150: val_loss did not improve from 0.00056

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model_aug.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model_aug.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')
